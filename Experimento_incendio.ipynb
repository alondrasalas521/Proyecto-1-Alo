# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
datos = pd.read_csv("incendios experimento_01-table.csv", skiprows = 6 )

# %%
datos.columns
# Out:
# Index(['[run number]', 'densidad', '[step]', 'porcentaje_quemado'], dtype='object')

# %%
x = datos["densidad"]
y = datos ["porcentaje_quemado"]

# %%
plt.plot( x, y, ".")
plt.xlabel("Densidad")
plt.ylabel("Porcentaje_quemado")
plt.show()
